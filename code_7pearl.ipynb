# %% [markdown]
# <a href="https://colab.research.google.com/github/michecue/myprojects-test1/blob/main/code_7pearl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello, 7 Pearl")
# Out:
# Hello, 7 Pearl
