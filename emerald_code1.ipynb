# %% [markdown]
# <a href="https://colab.research.google.com/github/michecue/myprojects-test1/blob/main/emerald_code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello 7-emerald")
# Out:
# hello 7-emerald
